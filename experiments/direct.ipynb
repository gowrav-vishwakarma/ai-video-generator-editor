# %%
from diffusers import DiffusionPipeline

pipe = DiffusionPipeline.from_pretrained("lllyasviel/FramePack_F1_I2V_HY_20250503")

prompt = "Astronaut in a jungle, cold color palette, muted colors, detailed, 8k"
image = pipe(prompt).images[0]
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/Development/influencer/.venv/lib/python3.12/site-packages/huggingface_hub/utils/_http.py:409, in hf_raise_for_status(response, endpoint_name)
#     408 try:
# --> 409     response.raise_for_status()
#     410 except HTTPError as e:
#
# File ~/Development/influencer/.venv/lib/python3.12/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://huggingface.co/lllyasviel/FramePack_F1_I2V_HY_20250503/resolve/main/model_index.json
#
# The above exception was the direct cause of the following exception:
#
# EntryNotFoundError                        Traceback (most recent call last)
# Cell In[3], line 3
#       1 from diffusers import DiffusionPipeline
# ----> 3 pipe = DiffusionPipeline.from_pretrained("lllyasviel/FramePack_F1_I2V_HY_20250503")
#       5 prompt = "Astronaut in a jungle, cold color palette, muted colors, detailed, 8k"
#       6 image = pipe(prompt).images[0]
#
# File ~/Development/influencer/.venv/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/Development/influencer/.venv/lib/python3.12/site-packages/diffusers/pipelines/pipeline_utils.py:773, in DiffusionPipeline.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     768     if pretrained_model_name_or_path.count("/") > 1:
#     769         raise ValueError(
#     770             f'The provided pretrained_model_name_or_path "{pretrained_model_name_or_path}"'
#     771             " is neither a valid local path nor a valid repo id. Please check the parameter."
#     772         )
# --> 773     cached_folder = cls.download(
#     774         pretrained_model_name_or_path,
#     775         cache_dir=cache_dir,
#     776         force_download=force_download,
#     777         proxies=proxies,
#     778         local_files_only=local_files_only,
#     779         token=token,
#     780         revision=revision,
#     781         from_flax=from_flax,
#     782         use_safetensors=use_safetensors,
#     783         use_onnx=use_onnx,
#     784         custom_pipeline=custom_pipeline,
#     785         custom_revision=custom_revision,
#     786         variant=variant,
#     787         dduf_file=dduf_file,
#     788         load_connected_pipeline=load_connected_pipeline,
#     789         **kwargs,
#     790     )
#     791 else:
#     792     cached_folder = pretrained_model_name_or_path
#
# File ~/Development/influencer/.venv/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/Development/influencer/.venv/lib/python3.12/site-packages/diffusers/pipelines/pipeline_utils.py:1415, in DiffusionPipeline.download(cls, pretrained_model_name, **kwargs)
#    1412         model_info_call_error = e  # save error to reraise it if model is not cached locally
#    1414 if not local_files_only:
# -> 1415     config_file = hf_hub_download(
#    1416         pretrained_model_name,
#    1417         cls.config_name,
#    1418         cache_dir=cache_dir,
#    1419         revision=revision,
#    1420         proxies=proxies,
#    1421         force_download=force_download,
#    1422         token=token,
#    1423     )
#    1424     config_dict = cls._dict_from_json_file(config_file)
#    1425     ignore_filenames = config_dict.pop("_ignore_files", [])
#
# File ~/Development/influencer/.venv/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/Development/influencer/.venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:1008, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, resume_download, force_filename, local_dir_use_symlinks)
#     988     return _hf_hub_download_to_local_dir(
#     989         # Destination
#     990         local_dir=local_dir,
#    (...)   1005         local_files_only=local_files_only,
#    1006     )
#    1007 else:
# -> 1008     return _hf_hub_download_to_cache_dir(
#    1009         # Destination
#    1010         cache_dir=cache_dir,
#    1011         # File info
#    1012         repo_id=repo_id,
#    1013         filename=filename,
#    1014         repo_type=repo_type,
#    1015         revision=revision,
#    1016         # HTTP info
#    1017         endpoint=endpoint,
#    1018         etag_timeout=etag_timeout,
#    1019         headers=hf_headers,
#    1020         proxies=proxies,
#    1021         token=token,
#    1022         # Additional options
#    1023         local_files_only=local_files_only,
#    1024         force_download=force_download,
#    1025     )
#
# File ~/Development/influencer/.venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:1071, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, proxies, token, local_files_only, force_download)
#    1067         return pointer_path
#    1069 # Try to get metadata (etag, commit_hash, url, size) from the server.
#    1070 # If we can't, a HEAD request error is returned.
# -> 1071 (url_to_download, etag, commit_hash, expected_size, xet_file_data, head_call_error) = _get_metadata_or_catch_error(
#    1072     repo_id=repo_id,
#    1073     filename=filename,
#    1074     repo_type=repo_type,
#    1075     revision=revision,
#    1076     endpoint=endpoint,
#    1077     proxies=proxies,
#    1078     etag_timeout=etag_timeout,
#    1079     headers=headers,
#    1080     token=token,
#    1081     local_files_only=local_files_only,
#    1082     storage_folder=storage_folder,
#    1083     relative_filename=relative_filename,
#    1084 )
#    1086 # etag can be None for several reasons:
#    1087 # 1. we passed local_files_only.
#    1088 # 2. we don't have a connection
#    (...)   1094 # If the specified revision is a commit hash, look inside "snapshots".
#    1095 # If the specified revision is a branch or tag, look inside "refs".
#    1096 if head_call_error is not None:
#    1097     # Couldn't make a HEAD call => let's try to find a local file
#
# File ~/Development/influencer/.venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:1531, in _get_metadata_or_catch_error(repo_id, filename, repo_type, revision, endpoint, proxies, etag_timeout, headers, token, local_files_only, relative_filename, storage_folder)
#    1529 try:
#    1530     try:
# -> 1531         metadata = get_hf_file_metadata(
#    1532             url=url, proxies=proxies, timeout=etag_timeout, headers=headers, token=token
#    1533         )
#    1534     except EntryNotFoundError as http_error:
#    1535         if storage_folder is not None and relative_filename is not None:
#    1536             # Cache the non-existence of the file
#
# File ~/Development/influencer/.venv/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/Development/influencer/.venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:1448, in get_hf_file_metadata(url, token, proxies, timeout, library_name, library_version, user_agent, headers)
#    1445 hf_headers["Accept-Encoding"] = "identity"  # prevent any compression => we want to know the real size of the file
#    1447 # Retrieve metadata
# -> 1448 r = _request_wrapper(
#    1449     method="HEAD",
#    1450     url=url,
#    1451     headers=hf_headers,
#    1452     allow_redirects=False,
#    1453     follow_relative_redirects=True,
#    1454     proxies=proxies,
#    1455     timeout=timeout,
#    1456 )
#    1457 hf_raise_for_status(r)
#    1459 # Return
#
# File ~/Development/influencer/.venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:286, in _request_wrapper(method, url, follow_relative_redirects, **params)
#     284 # Recursively follow relative redirects
#     285 if follow_relative_redirects:
# --> 286     response = _request_wrapper(
#     287         method=method,
#     288         url=url,
#     289         follow_relative_redirects=False,
#     290         **params,
#     291     )
#     293     # If redirection, we redirect only relative paths.
#     294     # This is useful in case of a renamed repository.
#     295     if 300 <= response.status_code <= 399:
#
# File ~/Development/influencer/.venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:310, in _request_wrapper(method, url, follow_relative_redirects, **params)
#     308 # Perform request and return if status_code is not in the retry list.
#     309 response = http_backoff(method=method, url=url, **params, retry_on_exceptions=(), retry_on_status_codes=(429,))
# --> 310 hf_raise_for_status(response)
#     311 return response
#
# File ~/Development/influencer/.venv/lib/python3.12/site-packages/huggingface_hub/utils/_http.py:420, in hf_raise_for_status(response, endpoint_name)
#     418 elif error_code == "EntryNotFound":
#     419     message = f"{response.status_code} Client Error." + "\n\n" + f"Entry Not Found for url: {response.url}."
# --> 420     raise _format(EntryNotFoundError, message, response) from e
#     422 elif error_code == "GatedRepo":
#     423     message = (
#     424         f"{response.status_code} Client Error." + "\n\n" + f"Cannot access gated repo for url {response.url}."
#     425     )
#
# EntryNotFoundError: 404 Client Error. (Request ID: Root=1-68274754-684e357936d1f48746c133b6;694512d3-c325-4f94-b5f9-008c11999890)
#
# Entry Not Found for url: https://huggingface.co/lllyasviel/FramePack_F1_I2V_HY_20250503/resolve/main/model_index.json.
